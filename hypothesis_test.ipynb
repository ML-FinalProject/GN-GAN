# %%
# !python -c "import torch; print(torch.__version__); print('CUDA available:', torch.cuda.is_available()); print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'no GPU')"
# Out:
# 2.4.1+cu118
# CUDA available: True
# NVIDIA RTX A6000

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !python train_hypothesis.py --flagfile ./config/GN-GAN_CIFAR10_BIGGAN.txt  --seed=0 --logdir=./logs/GN-BigGAN_CIFAR10_hypothesis_seed0

# %%
# !python train_hypothesis.py --flagfile ./config/GN-GAN_CIFAR10_BIGGAN.txt  --seed=0 --logdir=./logs/GN-BigGAN_CIFAR10_HYPOTHESIS_SEED0

# %%
# !python train_hypothesis.py --resume --flagfile ./config/GN-GAN_CIFAR10_BIGGAN.txt  --seed=0 --logdir=./logs/GN-BigGAN_CIFAR10_hypothesis_seed0

# %%
# !python train_hypothesis.py --gn_quasi_alpha=0.001 --flagfile ./config/GN-GAN_CIFAR10_BIGGAN.txt --seed=1 --logdir=./logs/GN-BigGAN_CIFAR10_hypothesis_seed1

# %%
# !python train_hypothesis.py --resume --gn_quasi_alpha=0.001 --flagfile ./config/GN-GAN_CIFAR10_BIGGAN.txt --seed=1 --logdir=./logs/GN-BigGAN_CIFAR10_hypothesis_seed1

# %%
# !python train_hypothesis.py --gn_quasi_alpha=0.005 --flagfile ./config/GN-GAN_CIFAR10_BIGGAN.txt --seed=2 --logdir=./logs/GN-BigGAN_CIFAR10_hypothesis_seed2
